# %% [markdown]
# ### <figure>
#   <IMG SRC="https://raw.githubusercontent.com/Sjvgaal/Public/main/38895-logo-nieuw-.jpeg" WIDTH=250 ALIGN="right">
# </figure>
#
# # E-WISTRA-pr1
# #### Elektrotechniek
# #### 2024/2025 - semester 1 - blok 2
#
# - Docent: Sophia de Jong
# - E-mail: s.dejong@hhs.nl
# - kamer: 1.047
#
# # P1: Introductie Python en inleiding Fourierreeks
#
#
# #### Inleveren via Brightspace uiterlijk om 23:59 op de dag voorafgaand aan het practicum in lesweek 13.
#
# *Vergeet niet om regelmatig je werk op te slaan.*

# %% [markdown]
# ## Vul in:
# **Student 1**

# %% [raw]
# Naam: Seb Geers
# Studentnummer: 22098941

# %% [markdown]
# **Student 2**

# %% [raw]
# Naam: Jay Heerspink
# Studentnummer: 23024143

# %% [markdown]
# # Praktische informatie

# %% [markdown]
# ### Samenwerking en individuele verantwoordelijkheid
# - De opgaven van dit notebook mogen door twee studenten samen gemaakt worden.
# - Met andere groepjes medestudenten overleggen mag, maar maak wel zelf de opgaven. Domweg van elkaar kopiëren of werk aan anderen geven is natuurlijk verboden. Dat geldt voor elke vorm van plagiaat. Het overnemen van antwoorden gegenereerd door AI valt ook onder plagiaat.
# - Beide studenten kunnen desgevraagd persoonlijk uitleg geven over de gegeven antwoorden en de gekozen en uitgevoerde oplossingsmethode.
# - Beide studenten zijn persoonlijk verantwoordelijk voor de inhoud en de tijdige inlevering.

# %% [markdown]
# ### Opbouw van dit notebook
# In dit notebook staat een beknopte uitleg over het werken in Python Notebooks. Daarna volgt informatie over enkele relevante libraries en functies die nodig zijn bij het onderwerp Fourierreeksen, gevolgd door verschillende opdrachten.
#
# Het is belangrijk om **alles** door te lezen, en **alle cellen** één voor één van boven naar beneden te runnen.
#
# LET OP: Pas in dit notebook de tekst, layout en code geschreven door de docent niet aan! Tenzij expliciet aangegeven dat dit de bedoeling is.
#
# *Dit is geen programmeervak. Bij het vak OOSPLC leer je programmeren in Python. Om de opdrachten uit te voeren hoef je alleen code te kopiëren en aan te passen.  In dit practicum wordt Python enkel als tool gebruikt om de wiskundige concepten van WISTRA beter te begrijpen. Je begrip van de wiskunde wordt beoordeeld.*

# %% [markdown]
# ### Beoordeling
# - Dit notebook wordt beoordeeld met een natuurlijk getal uit 1 t/m 10. Als dit notebook door twee studenten samen wordt gemaakt, dan krijgen beiden dezelfde beoordeling.
# - Het resultaat maakt deel uit van het practicumdeel van WISTRA. Om uiteindelijk een V (voldoende) te krijgen voor het totale practicum, moet aan een aantal eisen zijn voldaan. Zie hiervoor de studiewijzer.
# - Het niet voldoen aan de eisen zoals vermeld in dit notebook, in de studiewijzer of meegedeeld tijdens het practicum, kan de beoordeling negatief beïnvloeden.

# %% [markdown]
# ### Eisen waaraan dit notebook bij inleveren moet voldoen
# - Alle output moet verwijderd worden: dit doe je door met de rechtermuisknop ergens in dit notebook te klikken, en vervolgens te kiezen voor "Clear Outputs of All Cells" (of iets soortgelijks in het Nederlands).
# - De output die verschijnt na het runnen van dit notebook wordt beoordeeld.
#
# **Tip:**
# Speel zelf corrector. Werk de sheet door alsof je als docent aan het corrigeren bent. Ga na of dat goed loopt en of de beoogde output verschijnt.

# %% [markdown]
# ### Inleveren
# - Geef dit notebook de naam P1-student1-student2.ipynb, waarbij je de namen invult van studenten 1 en 2.
# - Upload dit notebook naar Brightspace, op de juiste plek: "Week 13: Python notebook P1".
# - Bewaar zelf een kopie van het ingeleverde werk en wijzig dit niet meer na het inleveren van het origineel. Dit kan van belang zijn als er bij het uploaden iets mis gaat.

# %% [markdown]
# ### Vragen
# Stel vragen zo veel mogelijk tijdens de practicumuren. Kom voorbereid, dan haal je er het meeste uit.

# %% [markdown]
# # Introductie Jupyter Notebooks <a name="jupyternb"></a>
# In dit vak werk je in Jupyter Notebooks. Jupyter Notebooks zijn een manier om opgemaakte tekst (zoals deze tekst) te combineren met Python code en de resultaten van de code, allemaal op één plek.

# %% [markdown]
# ## Cellen
# Notebooks zijn opgedeeld in cellen, zoals deze tekstcel die je nu leest. Deze tekstcel is opgemaakt in formattingtaal MarkDown.
#
# Als je één keer op de cel klikt kun je met keyboard shortcuts werken. Als je "Enter" drukt of dubbel klikt op de tekstcel, kun je de cel bewerken. (Doe dat niet.)
#
# Je kunt een cel invoegen en verwijderen met de knoppen rechtbovenin deze cel. (Probeer geen cellen te verwijderen.)
#
# Als je op "run" of "uitvoeren" klikt in toolbar, of "shift-enter" gebruikt, zal de cel "runnen". Bij een tekstcel zal het de MarkDown tekst "compilen" in opgemaakte (HTML) tekst. Als het een codecel is, worden de Pythoncommando's uitgevoerd.

# %% [markdown]
# ## Codecel runnen
#
# Je kunt commando's aan de Pythonkernel geven door Pythoncommando's in de codecellen te typen. Een voorbeeld staat hieronder.
# Om dit commando's naar de Pythonkernel te sturen zijn er meerdere opties. Selecteer de cel, en:
#
# 1. Klik op de **Run** ("Play") knop in de toolbar. Dit runt de cel en selecteert de volgende cel.
# 2. Gebruik **Shift-Enter**. Dit doet hetzelfde.
# 3. Gebruik **Ctrl-Enter**. Dit runt de cel maar houdt deze geselecteerd (handig als je een cel meerdere keren wilt runnen).

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht A </div>
#
# * Oefen met het runnen van onderstaande cel op deze 3 manieren
# * Print jullie eigen namen

# %% [markdown]
# **Antwoord Opdracht A:**

# %%
print("Seb Geers")
# print jullie eigen namen:
# Out:
# Seb Geers

# %% [markdown]
# ## Comments
# Als je een regel in een codecel begint met `#` zal Python deze regel negeren. Dit kun je gebruiken om **comments** toe te voegen aan je code. Zie de comment `# print jullie eigen namen:` hierboven.

# %% [markdown]
# ## De kernel starten en stoppen
# Als je een notebook voor de eerste keer opent, wordt er een nieuwe kernel voor je gestart met niets in het geheugen.
#
# Soms wil je de kernel van een notebook herstarten. Bijvoorbeeld om alle variabelen leeg te maken en je code opnieuw te runnen (een fresh start).
#
# Soms móet je de kernel herstarten als de kernel is gecrasht. De status van de kernel kun je onderin het scherm zien (bijvoorbeeld "Idle" of "Busy", en rechtsbovenin aan het lege tot volle cirkel-icoon.
#
# Om de kernel te herstarten zijn er twee handige knoppen op de toolbar:
# - "Stop" (vierkantje): vertelt de kernel te stoppen met het runnen van de code waar de kernel mee bezig was, maar maakt geheugen niet leeg.
# - "Restart" (cirkelvormige pijl): kills de kernel (maakt geheugen leeg), en start een nieuwe kernel voor het notebook.

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht B </div>
#
# Run de volgende cel die `a` en `b` definieert en vervolgens 10 minuten wacht:

# %%
a=3
b=5
from time import sleep
sleep(10*60)

# %% [markdown]
# Je zult doorhebben dat als deze cel wordt uitgevoerd, de tekst links ervan `[*]:` toont. De * geeft aan dat de cel op dit moment wordt uitgevoerd en verandert in een getal als de cel klaar is. Je ziet ook dat het cirkel-icoon rechtsbovenin gevuld wordt. Als je veel geduld hebt kun je wachten, maar het is waarschijnlijk handig om de kernel te stoppen.
#
# 1. Stop de kernel.
# 2. Geef hieronder een lijst van de opgeslagen variabelen door gebruik te maken van het `%whos` commando.
# 3. Restart daarna de kernel. Welke variabelen zijn in het geheugen opgeslagen voor en na de restart?

# %%
# %whos

# %% [markdown]
# **Antwoord Opdracht B:**

# %% [raw]
# Voor:
# a                      int                           3
# b                      int                           5
# dataframe_columns      function                      <function dataframe_columns at 0x72c2d27f6520>
# dataframe_hash         function                      <function dataframe_hash at 0x72c2d27f6a20>
# dtypes_str             function                      <function dtypes_str at 0x72c2d27f4f40>
# get_dataframes         function                      <function get_dataframes at 0x72c2d27f58a0>
# getpass                module                        <module 'getpass' from '/<...>b/python3.11/getpass.py'>
# hashlib                module                        <module 'hashlib' from '/<...>b/python3.11/hashlib.py'>
# import_pandas_safely   function                      <function import_pandas_safely at 0x72c2d27f5f80>
# is_data_frame          function                      <function is_data_frame at 0x72c2d27f6840>
# json                   module                        <module 'json' from '/opt<...>on3.11/json/__init__.py'>
# sleep                  builtin_function_or_method    <built-in function sleep>
#
# Na:
# Niks

# %% [markdown]
# # Handige functies in SymPy <a name="sympy"></a>
#
# We zullen gebruikmaken van verschillende Pythonmodules. Een veelgebruikte Pythonmodule is NumPy. Met NumPy kun je op een eenvoudige manier lijsten met data genereren en analyseren. NumPy staat voor *Numerical Python*: berekeningen met grote datasets kunnen snel uitgevoerd worden met numerieke methoden. In dit eerste notebook willen we echter graag Fourierreeksen exact berekenen. Daarom gebruiken we SymPy: *Symbolic Python*.
#
# Met SymPy kun je symbolisch rekenen. In plaats van getallen blijven de symbolen staan.
#
# Onderstaande cel importeert de SymPy-module. **Run de cel:**

# %%
import sympy as sp

# %% [markdown]
# ### De Heaviside functie

# %% [markdown]
# Laten we de eerste handige functie importeren: `Heaviside`. **Run de cel:**

# %%
from sympy import Heaviside
from sympy.abc import t # dit importeert t als een symbolische variabele

# %% [markdown]
# We kunnen nu een signaal definiëren met een functie, bijvoorbeeld
# $f(t) =
# \begin{cases}
# 3 & \text{ voor }\ 1 \leq t<3 \\
# 0 & \text{ elders}
# \end{cases}
# $
#
#
# **Run de cel:**

# %%
def signaal1(t):
    return 3*(Heaviside(t-1)-Heaviside(t-3))

# %% [markdown]
# Het printen van deze functie levert geen mooie output op. Probeer maar.

# %%
print(signaal1(t))
# Out:
# -3*Heaviside(t - 3) + 3*Heaviside(t - 1)

# %% [markdown]
# Het object `signaal1(t)` is een "callable" Python functie. Om de functie op een mooie en leesbare manier weer te geven, importeren we `sympify`. **Run de cel:**

# %%
from sympy import sympify
sympify(signaal1(t))
# Out:
# -3*Heaviside(t - 3) + 3*Heaviside(t - 1)

# %% [markdown]
# De functie `sympify` moet ook worden toegepast bij het plotten van het signaal met de SymPy-plotfunctie. Voor het plotten importeren we eerste de module `matplotlib`, en stellen we de afmetingen van de plot in. **Run onderstaande cellen:**

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (5, 3)

# %%
from sympy import plot
plot(sympify(signaal1(t)),(t,-3,5),xlim=[-3,5], ylim=[-3,4],xlabel='$t$',ylabel='$y$')
plt.show()

# %% [markdown]
# ### Een reeks verschoven kopieën van een functie maken
# Voor begrip van Fourierreeksen is het handig om de grafiek van een signaal met de grafiek van zijn Fourierreeks te kunnen vergelijken.
#
# Hieronder wordt de functie `verschoven_kopie` gedefinieerd waarmee met een signaal dat op slechts één periode gedefinieerd is, een nieuw signaal gemaakt kan worden dat bestaat uit een aantal verschoven kopieën van het originele signaal. Zo lijkt het nieuwe signaal periodiek en is vergelijking met de Fourierreeks eenvoudiger.

# %%
def verschoven_kopie(f0, t0, T, N, p0):
    """
    Creëert een nieuw signaal bestaande uit verschoven kopieën van het inputsignaal.

    Parameters:
    - f0: het inputsignaal
    - t0: het vensterbegin
    - T : de vensterbreedte
    - N : het aantal kopieën
    - p0: de verschuiving van de kopieën p0*T naar rechts
    
    Returns:
    - Het nieuwe signaal.
    """

    t1 = t0 + T
    def signaal(x):
        kopie_signaal = 0
        for n in range(p0, p0+N):
            kopie_signaal += (Heaviside(t-n*T-t0)-Heaviside(t-n*T-t1))*f0(t-n*T)
        return kopie_signaal
    return signaal

# %% [markdown]
# Laten we de functie `verschoven_kopie` toepassen op `signaal1` om een nieuw signaal te maken. **Run onderstaande cel:**

# %%
signaal2 = verschoven_kopie(signaal1,0,4,4,0)

plot(sympify(signaal2(t)),(t,-5,20),xlim=[-5,20], ylim=[-1,4],xlabel='$t$',ylabel='$y$')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht C </div>
#
# Verander, in de cel hieronder, de input van de functie `verschoven_kopie` om te ontdekken wat de inputvariabelen `t0`, `T`, `N` en `p0` precies doen.
#
# Omschrijf in je eigen woorden hoe deze inputvariabelen het outputsignaal veranderen.

# %%
signaal3 = verschoven_kopie(signaal1,2,5,2,2)

plot(sympify(signaal3(t)),(t,-5,20),xlim=[-5,20], ylim=[-1,4],xlabel='$t$',ylabel='$y$')
plt.show()

# %% [markdown]
# **Antwoord Opdracht C:**

# %% [raw]
# t0: Verplaatste de linker of rechter flank
# T: Periode tijd
# N: Het aantal periodes
# p0: Verplaatst de periodes

# %% [markdown]
# # De reële Fourierreeks berekenen

# %% [markdown]
# Met de SymPy functie `fourier_series` kan een deel van de reële Fourierreeks van een signaal berekend worden. Deze functie neemt als input het signaal, en een triplet met de variabele en het interval waarover de Fourierreeks bepaald moet worden.

# %%
from sympy import fourier_series

# %% [markdown]
# De functie waarvan de reële Fourierreeks wordt berekend, moet periodiek zijn. Neem bijvoorbeeld de functie
# $f(t) =
# \begin{cases}
# 3 & \text{ voor }\ 1\leq t<3 \\
# 0 & \text{ elders}
# \end{cases}
# $
# $\ \ \ $ en verder periodiek met periode 4.
#
# Dit signaal kunnen we bouwen (op een eindig interval) met de functie `verschoven_kopie`.

# %%
signaal4 = verschoven_kopie(signaal1,0,4,4,-1)

plot(sympify(signaal4(t)),(t,-4,12),xlim=[-4,12],ylim=[-1,4],xlabel='$t$',ylabel='$y$')
plt.show()

# %% [markdown]
# De SymPy functie `fourier_series` neemt één periode van de periodieke functie als input. Willen we de reële Fourierreeks bepalen van `signaal4`, dan hoeven we alleen `signaal4` als input te geven met t van 0 tot 4. (Bijvoorbeeld; een ander interval dat één periode vangt werkt ook.) Het is wat betreft rekenkracht beter om `signaal1` als input te geven op dit interval (de kopieën zijn overbodig).

# %%
fourierreeks1 = fourier_series(signaal1(t), (t, 0, 4))
sympify(fourierreeks1) # dit is beter leesbaar dan print()
# Out:
# FourierSeries(-3*Heaviside(t - 3) + 3*Heaviside(t - 1), (t, 0, 4), (3/2, SeqFormula((-3*Piecewise((1, Eq(_n, 0)), (2*sin(_n*pi/2)/(_n*pi), True)) + 3*Piecewise((3, Eq(_n, 0)), (2*sin(3*_n*pi/2)/(_n*pi), True)))*cos(_n*pi*t/2)/2, (_n, 1, oo)), SeqFormula((-3*Piecewise((0, Eq(_n, 0)), (-2*cos(_n*pi/2)/(_n*pi), True)) + 3*Piecewise((0, Eq(_n, 0)), (-2*cos(3*_n*pi/2)/(_n*pi), True)))*sin(_n*pi*t/2)/2, (_n, 1, oo))))

# %% [markdown]
# De eerste termen van de reële Fourierreeks worden getoond. We kunnen aangeven voor hoeveel frequenties de reeks berekend dient te worden. Hiervoor gebruiken we de functie `truncate`. Bijvoorbeeld de eerste vier frequenties:

# %%
fourierreeks1_n4 = fourierreeks1.truncate(4)
sympify(fourierreeks1_n4)
# Out:
# -6*cos(pi*t/2)/pi + 2*cos(3*pi*t/2)/pi - 6*cos(5*pi*t/2)/(5*pi) + 3/2

# %% [markdown]
# Laten we deze Fourierreeks plotten.

# %%
plot(fourierreeks1_n4,(t,-4,12),xlim=[-4,12], ylim=[-1,4],xlabel='$t$',ylabel='$y$')
plt.show()

# %% [markdown]
# En nu de eerste zes frequenties:

# %%
fourierreeks1_n6 = fourierreeks1.truncate(6)
sympify(fourierreeks1_n6)
# Out:
# -6*cos(pi*t/2)/pi + 2*cos(3*pi*t/2)/pi - 6*cos(5*pi*t/2)/(5*pi) + 6*cos(7*pi*t/2)/(7*pi) - 2*cos(9*pi*t/2)/(3*pi) + 3/2

# %%
plot(fourierreeks1_n6,(t,-4,12),xlim=[-4,12], ylim=[-1,4],xlabel='$t$',ylabel='$y$')
plt.show()

# %% [markdown]
# Vergelijk de twee plots hierboven met de plot van het oorspronkelijke `signaal4`. Je ziet dat de Fourierreeks met de eerste zes frequenties het signaal (natuurlijk) beter benadert dan de Fourierreeks met de eerst vier frequenties.
#
# Hieronder worden de Fourierreeksen samen met het originele signaal geplot in één assenstelsel.

# %%
plot(sympify(signaal4(t)),fourierreeks1_n4,(t,-4,12),xlim=[-4,12], ylim=[-1,4],xlabel='$t$',ylabel='$y$')
plot(sympify(signaal4(t)),fourierreeks1_n6,(t,-4,12),xlim=[-4,12], ylim=[-1,4],xlabel='$t$',ylabel='$y$')
plt.show()

# %% [markdown]
# Helaas bestaat er geen SymPy functie die direct de complexe Fourierreeks berekent. We moeten deze dus zelf definiëren. Dit doen we de volgende keer.

# %% [markdown]
# # Eindpdrachten

# %% [markdown]
# ### Opdracht 1
# Gegeven is het signaal met het functievoorschrift
#
# $f(t)=
# \begin{cases}
#  3 & \text{voor  }\ 1\leq t<3\\
#  0 & \text{voor  }\ 3\leq t<6
# \end{cases} \ \ \ $  en verder periodiek met periode 5.

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht 1a </div>
#
# Pas de functie `verschoven_kopie` toe op `signaal1` om $f(t)$ te creëren en te plotten op het interval [-5, 20].

# %%
# Antwoord 1a
signaal5 = verschoven_kopie(signaal1,0,5,4,0)

plot(sympify(signaal5(t)),(t,-5,20),xlim=[-5,20], ylim=[-1,4],xlabel='$t$',ylabel='$y$')
plt.show()

# %% [markdown]
# Om de reële Fourierreeks te bepalen van $f(t)$, kan de functie `fourier_series` toegepast worden op `signaal1`.
#
# De functie `fourier_series` wordt twee keer toegepast  op `signaal1`, en de resultaten worden geplot:

# %%
reeksA = fourier_series(signaal1(t), (t, 0, 5))
reeksA_n4 = reeksA.truncate(4)

reeksB = fourier_series(signaal1(t), (t, 1, 5))
reeksB_n4 = reeksB.truncate(4)

plot(reeksA_n4,(t,-5,20),xlim=[-5,20], ylim=[-1,4],xlabel='$t$',ylabel='$y$')
plot(reeksB_n4,(t,-5,20),xlim=[-5,20], ylim=[-1,4],xlabel='$t$',ylabel='$y$')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht 1b </div>
# Beschrijf het verschil in input waarmee de twee reeksen gecreëerd zijn.

# %% [raw]
# Antwoord 1b
# Het begin van een periode is bij de eerste 1 en bij de tweede 2.

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht 1c </div>
#
# Is Fourierreeks A of B de juiste Fourierreeks van de functie $f(t)$? Verklaar je antwoord.

# %% [raw]
# Antwoord 1c
# Fourierreeks A is de goede omdat het de juiste periode heeft.

# %% [markdown]
# ### Opdracht 2
# Gegeven is het signaal met het functievoorschrift
#
# $f(t)=
# \begin{cases}
#  3 & \text{voor  }\ -\frac{\pi}{2}\leq t< \frac{\pi}{2}\\
#  -2 & \text{voor  }\ \ \ \ \ \ \frac{\pi}{2}\leq t< \frac{3\pi}{2}
# \end{cases} \ \ \ $  en verder periodiek met periode $2\pi$.

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht 2 </div>
#
# Bereken met de functie `fourier_series` de reële Fourierreeks van $f$ voor $n=0\ $  t/m  $\ n=5$, en toon de output.
#
# [Dit is schriftelijke opdracht R1. Vergelijk je antwoord!]

# %%
from sympy import pi # nodig in deze en volgende opgaven

# %%
# Antwoord 2
def signaal2(t):
    return 3*(Heaviside(t-(-pi/2)))-5*(Heaviside(t-(pi/2)))+2*(Heaviside(t-((3*pi)/2)))

plot(sympify(signaal2(t)),(t,-3,5),xlim=[-3,6], ylim=[-3,4],xlabel='$t$',ylabel='$y$')
plt.show()
fourierreeks2 = fourier_series(signaal2(t), (t, (-pi/2), (3*pi/2)))
fourierreeks2_n4 = fourierreeks2.truncate(4)
sympify(fourierreeks2_n4)
# Out:
# 10*cos(t)/pi - 10*cos(3*t)/(3*pi) + 2*cos(5*t)/pi + 1/2

# %% [markdown]
# ### Opdracht 3
# Gegeven is het signaal met het functievoorschrift
#
# $f(t)=
# \begin{cases}
#  3t & \text{voor  }\ \ \ \ \ \ 0\leq t< \pi \\
#  0 & \text{voor  }\ \ \ \ \ \ \pi \leq t< 2\pi
# \end{cases} \ \ \ $  en verder periodiek met periode $2\pi$.

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht 3 </div>
#
# Bereken met de functie `fourier_series` de reële Fourierreeks van $f$ voor $n=0\ $  t/m  $\ n=3$, en toon de output.
#
# [Dit is schriftelijke opdracht R2. Vergelijk je antwoord!]

# %%
# Antwoord 3
def signaal3(t):
    return (3*t)*(Heaviside(t)-Heaviside(t-pi))
plot(sympify(signaal3(t)),(t,-3,7),xlim=[-3,7], ylim=[-3,10],xlabel='$t$',ylabel='$y$')
plt.show()
fourierreeks3 = fourier_series(signaal3(t), (t, 0, 2*pi))
fourierreeks3_n4 = fourierreeks3.truncate(4)
sympify(fourierreeks3_n4)
# Out:
# 3*sin(t) - 3*sin(2*t)/2 + sin(3*t) - 6*cos(t)/pi - 2*cos(3*t)/(3*pi) + 3*pi/4

# %% [markdown]
# ### Opdracht 4
# Gegeven is het signaal met het functievoorschrift
#
# $g(t)=
# \begin{cases}
#  2 & \text{voor  }\ 0\leq t<\pi\\
#  1 & \text{voor  }\ \pi\leq t<2\pi
# \end{cases} \ \ \ $  en verder periodiek met periode $2\pi$.

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht 4a </div>
#
# Bereken met de functie `fourier_series` de reële Fourierreeks van $g$ die de eerste drie frequenties bevat, en toon de output.

# %%
# Antwoord 4a
def signaal4(t):
    return 2*(Heaviside(t))-(Heaviside(t-pi)) 
plot(sympify(signaal4(t)),(t,-3,7),xlim=[-3,7], ylim=[-3,10],xlabel='$t$',ylabel='$y$')
plt.show()
fourierreeks4 = fourier_series(signaal4(t), (t, 0, 2*pi))
fourierreeks4_n4 = fourierreeks4.truncate(3)
sympify(fourierreeks4_n4)
# Out:
# 2*sin(t)/pi + 2*sin(3*t)/(3*pi) + 3/2

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht 4b </div>
#
# Maak met de functie `verschoven_kopie` het signaal $g$ op (minimaal) het interval [0, $8\pi$].

# %%
# Antwoord 4b
signaal5 = verschoven_kopie(signaal4,0,2*pi,4,0)
plot(sympify(signaal5(t)),(t,0,8*pi),xlim=[-3,9*pi], ylim=[-3,4],xlabel='$t$',ylabel='$y$')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht 4c </div>
#
# Plot het signaal $g$ en de Fourierreeks uit opdracht **a** samen in één assenstelsel op het interval [0, $8\pi$]. (Tip: voeg `axis_center=(0,0)` toe om de x-as op de juiste plaats te houden.)

# %%
# Antwoord 4c
plot(sympify(signaal5(t)),(fourierreeks4_n4),(t,0,8*pi),xlim=[-3,9*pi], ylim=[-3,4],xlabel='$t$',ylabel='$y$')

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht 4d </div>
#
# Herhaal opdracht **a** en opdracht **c** voor een Fourierreeks die de eerste vijf frequenties bevat. (Vergeet niet de formule van de reeks te tonen.)

# %%
# Antwoord 4d
fourierreeks4_n5 = fourierreeks4.truncate(4)
sympify(fourierreeks4_n5)
plot(sympify(signaal5(t)),(fourierreeks4_n5),(t,0,8*pi),xlim=[-3,9*pi], ylim=[-3,4],xlabel='$t$',ylabel='$y$')
plt.show()
fourierreeks4 = fourier_series(signaal4(t), (t, 0, 2*pi))
fourierreeks4_n4 = fourierreeks4.truncate(4)
sympify(fourierreeks4_n4)
# Out:
# 2*sin(t)/pi + 2*sin(3*t)/(3*pi) + 2*sin(5*t)/(5*pi) + 3/2

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht 4e </div>
#
# Herhaal opdracht **a** en opdracht **c** voor een Fourierreeks die de eerste tien frequenties bevat. (Vergeet niet de formule van de reeks te tonen.)

# %%
# Antwoord 4e
fourierreeks4_n5 = fourierreeks4.truncate(6)
sympify(fourierreeks4_n5)
plot(sympify(signaal5(t)),(fourierreeks4_n5),(t,0,8*pi),xlim=[-3,8*pi], ylim=[-3,4],xlabel='$t$',ylabel='$y$')
plt.show()
fourierreeks4 = fourier_series(signaal4(t), (t, 0, 2*pi))
fourierreeks4_n4 = fourierreeks4.truncate(6)
sympify(fourierreeks4_n4)
# Out:
# 2*sin(t)/pi + 2*sin(3*t)/(3*pi) + 2*sin(5*t)/(5*pi) + 2*sin(7*t)/(7*pi) + 2*sin(9*t)/(9*pi) + 3/2

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht 4f </div>
#
# Wat zijn de overeenkomsten in de plots uit onderdelen **c**, **d** en **e**? Verklaar deze overeenkomsten.

# %% [raw]
# Antwoord 4f
# De fourierreeks probeert het bloksignaal te volgen, bij elke flank is de piek iets groter dit komt omdat er een steilere helling moet komen.

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht 4g </div>
#
# Wat verandert er in de plots uit onderdelen **c**, **d** en **e** als $n$ toeneemt? Verklaar deze verandering(en).

# %% [raw]
# Antwoord 4g
# Het aantal kronkels op de blokgoolf, dit komt omdat de fourierreeks uit meer sinussen bestaat bij een hogere n.

# %% [markdown]
# ### Opdracht 5
# Gegeven is het signaal met het functievoorschrift
#
# $h(t)=
# \begin{cases}
#  \ \ \ t & \text{voor  }\ 0\leq t<1\\
#  1-t & \text{voor  }\ 1\leq t<2
# \end{cases} \ \ \ $  en verder periodiek met periode $2$.

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht 5a </div>
#
# Bereken met de functie `fourier_series` de reële Fourierreeks van $h$ die de eerste drie frequenties bevat, en toon de output.

# %%
# Antwoord 5a
def signaal5(t):
    return t*Heaviside(t)+(1-t)*Heaviside(t-1)+(1-t)*Heaviside(t-1)
plot(sympify(signaal5(t)),(t,-3,7),xlim=[-3,7], ylim=[-3,10],xlabel='$t$',ylabel='$y$')
plt.show()
fourierreeks5 = fourier_series(signaal5(t), (t, 0, 2))
fourierreeks5_n3 = fourierreeks5.truncate(3)
sympify(fourierreeks5_n3)
# Out:
# -4*cos(pi*t)/pi**2 - 4*cos(3*pi*t)/(9*pi**2) + 1/2

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht 5b </div>
#
# Maak met de functie `verschoven_kopie` het signaal $h$ op (minimaal) het interval [0, 8].

# %%
# Antwoord 5b
signaal5v = verschoven_kopie(signaal5,0,2,4,0)
plot(sympify(signaal5v(t)),(t,0,8),xlim=[-3,8], ylim=[-3,2],xlabel='$t$',ylabel='$y$')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht 5c </div>
#
# Plot het signaal $h$ en de Fourierreeks uit opdracht **a** samen in één assenstelsel op het interval [0, 8].

# %%
# Antwoord 5c
fourierreeks5_n3 = fourierreeks5.truncate(3)
sympify(fourierreeks5_n3)
plot(sympify(signaal5v(t)),(fourierreeks5_n3),(t,0,8),xlim=[-3,8], ylim=[-3,2],xlabel='$t$',ylabel='$y$')
plt.show()
fourierreeks5 = fourier_series(signaal5(t), (t, 0, 2))
fourierreeks5_n3 = fourierreeks5.truncate(3)
sympify(fourierreeks5_n3)
# Out:
# -4*cos(pi*t)/pi**2 - 4*cos(3*pi*t)/(9*pi**2) + 1/2

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht 5d </div>
#
# Herhaal opdracht **a** en opdracht **c** voor een Fourierreeks die de eerste vijf frequenties bevat. (Vergeet niet de formule van de reeks te tonen.)

# %%
# Antwoord 5d
fourierreeks5_n5 = fourierreeks5.truncate(4)
sympify(fourierreeks5_n5)
plot(sympify(signaal5v(t)),(fourierreeks5_n5),(t,0,8),xlim=[-3,8], ylim=[-3,2],xlabel='$t$',ylabel='$y$')
plt.show()
fourierreeks5 = fourier_series(signaal5(t), (t, 0, 2))
fourierreeks5_n5 = fourierreeks5.truncate(4)
sympify(fourierreeks5_n5)
# Out:
# -4*cos(pi*t)/pi**2 - 4*cos(3*pi*t)/(9*pi**2) - 4*cos(5*pi*t)/(25*pi**2) + 1/2

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht 5e </div>
#
# Herhaal opdracht **a** en opdracht **c** voor een Fourierreeks die de eerste tien frequenties bevat. (Vergeet niet de formule van de reeks te tonen.)

# %%
# Antwoord 5e
fourierreeks5_n10 = fourierreeks5.truncate(6)
sympify(fourierreeks5_n10)
plot(sympify(signaal5v(t)),(fourierreeks5_n10),(t,0,8),xlim=[-3,8], ylim=[-3,2],xlabel='$t$',ylabel='$y$')
plt.show()
fourierreeks5 = fourier_series(signaal5(t), (t, 0, 2))
fourierreeks5_n4 = fourierreeks5.truncate(6)
sympify(fourierreeks5_n10)
# Out:
# -4*cos(pi*t)/pi**2 - 4*cos(3*pi*t)/(9*pi**2) - 4*cos(5*pi*t)/(25*pi**2) - 4*cos(7*pi*t)/(49*pi**2) - 4*cos(9*pi*t)/(81*pi**2) + 1/2

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht 5f </div>
#
# Wat zijn de overeenkomsten in de plots uit onderdelen **c**, **d** en **e**? Verklaar deze overeenkomsten.

# %% [raw]
# Antwoord 5f
# De fourierreeks volgt de zaagtand goed. Dit komt omdat het al de vorm heeft van een sinus

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht 5g </div>
#
# Wat verandert er in de plots uit onderdelen **c**, **d** en **e** als $n$ toeneemt? Verklaar deze verandering(en).

# %% [raw]
# Antwoord 5g
# De punten worden steeds scherper, dit komt doordat er steeds meer sinussen met een kleinere periode worden toegevoegd.

# %% [markdown]
# ### Opdracht 6
# Gegeven is het signaal met het functievoorschrift
#
# $k(t)=t(\pi-t) \ \ \text{voor  }\ 0\leq t<\pi \ \ $ en verder periodiek met periode $\pi$.

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht 6a </div>
#
# Bereken met de functie `fourier_series` de reële Fourierreeks van $k$ die de eerste drie frequenties bevat, en toon de output.

# %%
# Antwoord 6a
def signaal6(t):
    return t*(pi-t)*Heaviside(t)
plot(sympify(signaal6(t)),(t,-3,pi),xlim=[-3,7], ylim=[-3,10],xlabel='$t$',ylabel='$y$')
plt.show()
fourierreeks6 = fourier_series(signaal5(t), (t, 0, pi))
fourierreeks6_n3 = fourierreeks6.truncate(2)
sympify(fourierreeks6_n3)

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht 6b </div>
#
# Maak met de functie `verschoven_kopie` het signaal $k$ op (minimaal) het interval [0, 4$\pi$].

# %%
# Antwoord 6b
signaal6v = verschoven_kopie(signaal6,0,pi,4,0)
plot(sympify(signaal6v(t)),(t,0,4*pi),xlim=[-3,4*pi], ylim=[-3,4],xlabel='$t$',ylabel='$y$')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 # Antwoord 6b
# ----> 2 signaal6v = verschoven_kopie(signaal6,0,pi,4,0)
#       3 plot(sympify(signaal6v(t)),(t,0,4*pi),xlim=[-3,4*pi], ylim=[-3,4],xlabel='$t$',ylabel='$y$')
#       4 plt.show()
#
# NameError: name 'signaal6' is not defined

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht 6c </div>
#
# Plot het signaal $k$ en de Fourierreeks uit opdracht **a** samen in één assenstelsel op het interval [0, 4$\pi$].

# %%
# Antwoord 6c
fourierreeks6 = fourier_series(signaal6(t), (t, 0, pi))
fourierreeks6_n3 = fourierreeks6.truncate(4)
sympify(fourierreeks6_n3)
plot(sympify(signaal6v(t)),(fourierreeks6_n3),(t,0,4*pi),xlim=[-3,4*pi], ylim=[-3,4],xlabel='$t$',ylabel='$y$')
plt.show()
sympify(fourierreeks6_n3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 # Antwoord 6c
# ----> 2 fourierreeks6 = fourier_series(signaal6(t), (t, 0, pi))
#       3 fourierreeks6_n3 = fourierreeks6.truncate(4)
#       4 sympify(fourierreeks6_n3)
#
# NameError: name 'signaal6' is not defined

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht 6d </div>
#
# Herhaal opdracht **a** en opdracht **c** voor een Fourierreeks die de eerste vijf frequenties bevat. (Vergeet niet de formule van de reeks te tonen.)

# %%
# Antwoord 6d
fourierreeks6 = fourier_series(signaal6(t), (t, 0, pi))
fourierreeks6_n5 = fourierreeks6.truncate(6)
sympify(fourierreeks6_n5)
plot(sympify(signaal6v(t)),(fourierreeks6_n5),(t,0,4*pi),xlim=[-3,4*pi], ylim=[-3,4],xlabel='$t$',ylabel='$y$')
plt.show()
sympify(fourierreeks6_n5)

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht 6e </div>
#
# Herhaal opdracht **a** en opdracht **c** voor een Fourierreeks die de eerste tien frequenties bevat. (Vergeet niet de formule van de reeks te tonen.)

# %%
# Antwoord 6e
fourierreeks6 = fourier_series(signaal6(t), (t, 0, pi))
fourierreeks6_n10 = fourierreeks6.truncate(11)
sympify(fourierreeks6_n10)
plot(sympify(signaal6v(t)),(fourierreeks6_n10),(t,0,4*pi),xlim=[-3,4*pi], ylim=[-3,4],xlabel='$t$',ylabel='$y$')
plt.show()
sympify(fourierreeks6_n10)

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht 6f </div>
#
# Wat zijn de overeenkomsten in de plots uit onderdelen **c**, **d** en **e**? Verklaar deze overeenkomsten.

# %% [raw]
# Antwoord 6f
# De fourierreeks volgt het signaal. De nul wordt niet aangeraakt, dit komt doordat het een te scherpe hoek is.

# %% [markdown]
# <div class="alert alert-block alert-info"> Opdracht 6g </div>
#
# Wat verandert er in de plots uit onderdelen **c**, **d** en **e** als $n$ toeneemt? Verklaar deze verandering(en).

# %% [raw]
# Antwoord 6g
# De boog wordt steeds beter gevolgd en de punt wordt steeds scherper. Dit komt omdat het signaal steeds beter benaderd wordt.

# %% [markdown]
# ### Opdracht 7
# Vergelijk de uitkomsten van Opdrachten 4, 5 en 6 met elkaar. Welke verschillen zijn er als je kijkt naar hoe goed de Fourierreeks de gegeven functie benadert? Verklaar het antwoord.

# %% [raw]
# Antwoord 7:
# Bij opdracht 4 wordt de functie het slechtste benadert omdat dit signaal qua vorm ook het minste op een sinus/cosinus lijkt vervolgens wordt het zaagtand signaal al veel beter benadert en het signaal bij opdracht 6 is bijna identiek omdat het eigenlijk de modulus is van een sinus.

# %% [markdown]
# **Klaar? Lees de inlevereisen onder "Praktische informatie" nog eens door.**
